# %%
import pandas as pd
Manualtopics_df = pd.read_csv('../dataset/Manual_Topics.csv',sep=';')

# %%
Manualtopics_df
# Out:
#                       Topic                                           Question
# 0                 Gas Price    How did COVID-19 affect global gasoline prices?
# 1                 Gas Price    What are the Reasons for rising Gasprice in US?
# 2                 Gas Price  What is the average gasoline price per liter i...
# 3                 Gas Price  How international conflicts impact the fuel pr...
# 4                   Economy  What's the attitude of Americans towards budge...
# 5                   Economy  What's the attitude of Americans towards spend...
# 6                   Economy          What is the government expenditure in US?
# 7                   Economy         Is Globalisation good for economic growth?
# 8                   Economy           What is the outlook of Business Tourism?
# 9                   Economy              What is the projection of Global GDP?
# 10                  Economy         What is the forecast of United States GDP?
# ...

# %%
manual_topics_df = Manualtopics_df[['Question', 'Topic']]

# %%
manual_topics_df
# Out:
#                                              Question                    Topic
# 0     How did COVID-19 affect global gasoline prices?                Gas Price
# 1     What are the Reasons for rising Gasprice in US?                Gas Price
# 2   What is the average gasoline price per liter i...                Gas Price
# 3   How international conflicts impact the fuel pr...                Gas Price
# 4   What's the attitude of Americans towards budge...                  Economy
# 5   What's the attitude of Americans towards spend...                  Economy
# 6           What is the government expenditure in US?                  Economy
# 7          Is Globalisation good for economic growth?                  Economy
# 8            What is the outlook of Business Tourism?                  Economy
# 9               What is the projection of Global GDP?                  Economy
# 10         What is the forecast of United States GDP?                  Economy
# ...

# %%
manual_topics_df = manual_topics_df.rename(columns={'Question': 'Topic', 'Topic': 'Sector'})

# Now the column formerly known as 'Question' is 'Topic', and 'Topic' is now 'Sector'
print(manual_topics_df.head())
# Out:
#                                                Topic     Sector
# 0    How did COVID-19 affect global gasoline prices?  Gas Price
# 1    What are the Reasons for rising Gasprice in US?  Gas Price
# 2  What is the average gasoline price per liter i...  Gas Price
# 3  How international conflicts impact the fuel pr...  Gas Price
# 4  What's the attitude of Americans towards budge...    Economy

# %%
manual_topics_df
# Out:
#                                                 Topic                   Sector
# 0     How did COVID-19 affect global gasoline prices?                Gas Price
# 1     What are the Reasons for rising Gasprice in US?                Gas Price
# 2   What is the average gasoline price per liter i...                Gas Price
# 3   How international conflicts impact the fuel pr...                Gas Price
# 4   What's the attitude of Americans towards budge...                  Economy
# 5   What's the attitude of Americans towards spend...                  Economy
# 6           What is the government expenditure in US?                  Economy
# 7          Is Globalisation good for economic growth?                  Economy
# 8            What is the outlook of Business Tourism?                  Economy
# 9               What is the projection of Global GDP?                  Economy
# 10         What is the forecast of United States GDP?                  Economy
# ...

# %%
manual_topics_df.to_csv('manual_topics.csv', index=False)
